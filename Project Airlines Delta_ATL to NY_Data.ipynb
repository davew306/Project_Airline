# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_2019_path = "2019AirlineData.csv"
csv_2020_path = "2020AirlineData.csv"

# %%
airline_2019_df = pd.read_csv(csv_2019_path, encoding="utf-8")
airline_2019_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE  \
# 0           0        0      1545
# 1           0        0       770
# 2           0        0      1067
# 3           0        0      1329
# 4           0        0      1018
#
#                                  UNIQUE_CARRIER_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 4  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
#
#                                         CARRIER_NAME ORIGIN ORIGIN_CITY_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# ...

# %%
Delta_Atl = airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Delta Air Lines Inc.')&(airline_2019_df['ORIGIN']=='ATL')& (airline_2019_df['DEST']=='LGA')& (airline_2019_df['PASSENGERS']>= 1000)]
Delta_Atl.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 251296       53509    40286       762  Delta Air Lines Inc.
# 251357       54809    43905       762  Delta Air Lines Inc.
# 251642       67439    41497       762  Delta Air Lines Inc.
# 251644       67738    37752       762  Delta Air Lines Inc.
# 251652       68153    42292       762  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 251296  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251357  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251642  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251644  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251652  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 251296  2019        1      2               2
# 251357  2019        1      1               2
# ...

# %%
Delta_Atl_LGA = Delta_Atl.sort_values("MONTH", ascending=True)
Delta_Atl_LGA.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 251357       54809    43905       762  Delta Air Lines Inc.
# 251296       53509    40286       762  Delta Air Lines Inc.
# 251652       68153    42292       762  Delta Air Lines Inc.
# 251662       68939    39069       762  Delta Air Lines Inc.
# 251708       74346    42699       762  Delta Air Lines Inc.
# 251689       72275    33371       762  Delta Air Lines Inc.
# 251687       71932    33517       762  Delta Air Lines Inc.
# 251715       75159    32638       762  Delta Air Lines Inc.
# 251644       67738    37752       762  Delta Air Lines Inc.
# 251677       71033    46481       762  Delta Air Lines Inc.
# 251642       67439    41497       762  Delta Air Lines Inc.
# 251738       77735    41135       762  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 251357  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# ...

# %%
Delta_Atl_LGA
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 251357       54809    43905       762  Delta Air Lines Inc.
# 251296       53509    40286       762  Delta Air Lines Inc.
# 251652       68153    42292       762  Delta Air Lines Inc.
# 251662       68939    39069       762  Delta Air Lines Inc.
# 251708       74346    42699       762  Delta Air Lines Inc.
# 251689       72275    33371       762  Delta Air Lines Inc.
# 251687       71932    33517       762  Delta Air Lines Inc.
# 251715       75159    32638       762  Delta Air Lines Inc.
# 251644       67738    37752       762  Delta Air Lines Inc.
# 251677       71033    46481       762  Delta Air Lines Inc.
# 251642       67439    41497       762  Delta Air Lines Inc.
# 251738       77735    41135       762  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 251357  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# ...

# %%
# import calendar
# listmonths = Delta_Atl_LGA['MONTH']
# for x in listmonths:
#     #print(calendar.month_name[x])
#     Delta_Atl_LGA.loc[(x-1),'MONTH']= calendar.month_name[x]
    
# Delta_Atl_LGA

# %%
airline_2020_df = pd.read_csv(csv_2020_path, encoding="utf-8")
airline_2020_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE UNIQUE_CARRIER_NAME      CARRIER_NAME ORIGIN  \
# 0           0        0       104    Republic Airline  Republic Airline    RSW
# 1           0        0        77    Republic Airline  Republic Airline    RSW
# 2           0        0        30    Republic Airline  Republic Airline    SAV
# 3           0        0       228    Republic Airline  Republic Airline    STL
# 4           0        0       466    Republic Airline  Republic Airline    LNK
#
#   ORIGIN_CITY_NAME DEST              DEST_CITY_NAME  YEAR  QUARTER  MONTH  \
# 0   Fort Myers, FL  MIA                   Miami, FL  2020        1      1
# 1   Fort Myers, FL  SRQ      Sarasota/Bradenton, FL  2020        1      1
# 2     Savannah, GA  HHH             Hilton Head, SC  2020        1      1
# 3    St. Louis, MO  CID  Cedar Rapids/Iowa City, IA  2020        1      1
# 4      Lincoln, NE  ORD                 Chicago, IL  2020        1      1
#
#    DISTANCE_GROUP
# 0               1
# ...

# %%
Delta_Atl_20 = airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Delta Air Lines Inc.')&(airline_2020_df['ORIGIN']=='ATL')& (airline_2020_df['DEST']=='LGA')& (airline_2020_df['PASSENGERS']>= 1000)]
Delta_Atl_20.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 170737        4319    55049       762  Delta Air Lines Inc.
# 178965        6462    75366       762  Delta Air Lines Inc.
# 187221       12047    43849       762  Delta Air Lines Inc.
# 189116       15390    39525       762  Delta Air Lines Inc.
# 189354       16038    32837       762  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 170737  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 178965  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 187221  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 189116  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 189354  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 170737  2020        2      4               2
# 178965  2020        2      5               2
# ...

# %%
Delta_Atl_LGA_20 = Delta_Atl.sort_values("MONTH", ascending=True)
Delta_Atl_LGA_20.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 251357       54809    43905       762  Delta Air Lines Inc.
# 251296       53509    40286       762  Delta Air Lines Inc.
# 251652       68153    42292       762  Delta Air Lines Inc.
# 251662       68939    39069       762  Delta Air Lines Inc.
# 251708       74346    42699       762  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 251357  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251296  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251652  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251662  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 251708  Delta Air Lines Inc.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 251357  2019        1      1               2
# 251296  2019        1      2               2
# ...

# %%
Delta_ATL_LGA_19_20 = pd.merge(Delta_Atl_LGA, Delta_Atl_LGA_20, how="outer")

# %%
y_values_19_Pass = Delta_Atl_LGA['PASSENGERS']

# %%
x_values_19_Pass=Delta_Atl_LGA['MONTH']

# %%
y_values_20_Pass = Delta_Atl_LGA_20['PASSENGERS']

# %%
x_values_20_Pass = Delta_Atl_LGA_20['MONTH']

# %%
plt.title("Delta Route ATL to LGA (New York), 2019 vs 2020 Passenger Volume")
plt.xlabel("Months")
plt.ylabel("Passengers")

plt.scatter(x_values_19_Pass, y_values_19_Pass, marker="o", facecolors="blue", edgecolors="black")
plt.scatter(x_values_20_Pass, y_values_20_Pass, marker="o", facecolors="red", edgecolors="black")

ax = plt.subplot(111)
ax.plot(x_values_19_Pass, y_values_19_Pass, label='2019 Passengers')
ax.plot(x_values_20_Pass, y_values_20_Pass, label='2020 Passengers')
ax.legend(loc='lower right', bbox_to_anchor=(1, .08), shadow=True, ncol=1)
# Out:
# /Users/ricardobenitez/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
y_values_19_Freight = Delta_Atl_LGA['FREIGHT']

# %%
x_values_19_Freight=Delta_Atl_LGA['MONTH']

# %%
y_values_20_Freight = Delta_Atl_LGA_20['FREIGHT']

# %%
x_values_20_Freight =Delta_Atl_LGA_20['MONTH']

# %%
plt.title("Delta Route ATL to LGA( New York, 2019 vs 2020 Freight Volume")
plt.xlabel("Months")
plt.ylabel("Freight (Pounds)")

plt.scatter(x_values_19_Freight, y_values_19_Freight, marker="o", facecolors="green", edgecolors="black")
plt.scatter(x_values_20_Freight, y_values_20_Freight, marker="o", facecolors="orange", edgecolors="black")

ax1 = plt.subplot(111)
ax1.plot(x_values_19_Freight, y_values_19_Freight, label='2019 Freight')
ax1.plot(x_values_20_Freight, y_values_20_Freight, label='2020 Freight')
ax1.legend(loc='lower right', bbox_to_anchor=(1,-.025), shadow=True, ncol=1)
# Out:
# /Users/ricardobenitez/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
Atl_LGA_Market = airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Delta Air Lines Inc.')& (airline_2019_df['CARRIER_NAME']=='United Air Lines Inc.')& (airline_2019_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2019_df['CARRIER_NAME']=='Spirit Air Lines')&airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2019_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LGA')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_LGA_Market
# Out:
#   File "<ipython-input-27-4b566b6e21e6>", line 2
#     Atl_LGA_Market
#                  ^
# SyntaxError: invalid syntax

# %%
)&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_LAG_American_19_Sorted = Atl_LAG_American.sort_values("MONTH")

# %%
Atl_LGA_American_19_Sorted= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LGA')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_LGA_American_19_Sorted.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 200979        4391        5       762  American Airlines Inc.
# 205085        4776        2       762  American Airlines Inc.
# 207164        4994        0       762  American Airlines Inc.
# 207357        5013       22       762  American Airlines Inc.
# 207969        5083        1       762  American Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 200979  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 205085  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 207164  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 207357  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 207969  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 200979  2019        1      2               2
# 205085  2019        1      1               2
# ...

# %%
y_values_19_American = Atl_LGA_American_19_Sorted['PASSENGERS']

# %%
x_values_19_American = Atl_LGA_American_19_Sorted['MONTH']

# %%
Atl_LGA_Frontier_19_Sorted= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LGA')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_LGA_Frontier_19_Sorted= Atl_LGA_Frontier_19_Sorted.sort_values("MONTH")
Atl_LGA_Frontier_19_Sorted.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 197694        4134        0       762  Frontier Airlines Inc.
# 201264        4416        0       762  Frontier Airlines Inc.
# 200840        4379        0       762  Frontier Airlines Inc.
# 202667        4546        0       762  Frontier Airlines Inc.
# 205695        4842        0       762  Frontier Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 197694  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 201264  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 200840  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 202667  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 205695  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 197694  2019        1      1               2
# 201264  2019        1      2               2
# ...

# %%
y_values_19_Frontier = Atl_LGA_Frontier_19_Sorted['PASSENGERS']

# %%
x_values_19_Frontier = Atl_LGA_Frontier_19_Sorted['MONTH']

# %%
Atl_LGA_SW_19= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LGA')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_LGA_SW_19_Sorted = Atl_LGA_SW_19.sort_values("MONTH")
Atl_LGA_SW_19_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 237433       13949    23374       762  Southwest Airlines Co.
# 237203       13808    24614       762  Southwest Airlines Co.
# 241503       17702    23717       762  Southwest Airlines Co.
# 240691       16814    23501       762  Southwest Airlines Co.
# 242966       19459    24994       762  Southwest Airlines Co.
# 241538       17734    21979       762  Southwest Airlines Co.
# 242063       18337    18599       762  Southwest Airlines Co.
# 242001       18261    24851       762  Southwest Airlines Co.
# 240547       16677    23704       762  Southwest Airlines Co.
# 240444       16558    18585       762  Southwest Airlines Co.
# 240263       16374    24523       762  Southwest Airlines Co.
# 242818       19275    26765       762  Southwest Airlines Co.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 237433  Southwest Airlines Co.    ATL      Atlanta, GA  LGA   New York, NY
# ...

# %%
y_values_19_SW = Atl_LGA_SW_19_Sorted['PASSENGERS']

# %%
x_values_19_SW = Atl_LGA_SW_19_Sorted['MONTH']

# %%
#Atl_LGA_UNIT_19= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='WestJet')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LGA')&(airline_2019_df['PASSENGERS']>= 1000)]
#Atl_LGA_UNIT_Sorted = Atl_LGA_Spirit_19.sort_values("MONTH")
#Atl_LGA_UNIT_Sorted.head()
# Out:
# Empty DataFrame
# Columns: [PASSENGERS, FREIGHT, DISTANCE, UNIQUE_CARRIER_NAME, CARRIER_NAME, ORIGIN, ORIGIN_CITY_NAME, DEST, DEST_CITY_NAME, YEAR, QUARTER, MONTH, DISTANCE_GROUP]
# Index: []

# %%
#y_values_19_Spirit = Atl_LGA_Spirit_Sorted['PASSENGERS']

# %%
#x_values_19_Spirit = Atl_LGA_Spirit_Sorted['MONTH']

# %%
Atl_LGA_American_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 100)]
Atl_LGA_American_20_Sorted = Atl_LGA_American_20.sort_values("MONTH")
Atl_LGA_American_20_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 170529        4283      620       762  American Airlines Inc.
# 172212        4602        3       762  American Airlines Inc.
# 150941        2244      434       762  American Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 170529  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 172212  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 150941  American Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 170529  2020        1      1               2
# 172212  2020        1      2               2
# 150941  2020        1      3               2

# %%
Atl_LGA_Frontier_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 100)]
Atl_LGA_Frontier_20_Sorted = Atl_LGA_Frontier_20.sort_values("MONTH")
Atl_LGA_Frontier_20_Sorted.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 167653        3834        0       762  Frontier Airlines Inc.
# 166792        3724        0       762  Frontier Airlines Inc.
# 152583        2360        0       762  Frontier Airlines Inc.
# 103142         273        0       762  Frontier Airlines Inc.
# 155836        2611        0       762  Frontier Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 167653  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 166792  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 152583  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 103142  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 155836  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 167653  2020        1      1               2
# 166792  2020        1      2               2
# ...

# %%
Atl_LGA_SW_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 25)]
Atl_LGA_SW_20_Sorted = Atl_LGA_SW_20.sort_values("MONTH")
Atl_LGA_SW_20_Sorted.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 188444       13990    31586       762  Southwest Airlines Co.
# 187960       13173    28422       762  Southwest Airlines Co.
# 180591        7080    30909       762  Southwest Airlines Co.
# 117787         701    36257       762  Southwest Airlines Co.
# 95122          147     5587       762  Southwest Airlines Co.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 188444  Southwest Airlines Co.    ATL      Atlanta, GA  LGA   New York, NY
# 187960  Southwest Airlines Co.    ATL      Atlanta, GA  LGA   New York, NY
# 180591  Southwest Airlines Co.    ATL      Atlanta, GA  LGA   New York, NY
# 117787  Southwest Airlines Co.    ATL      Atlanta, GA  LGA   New York, NY
# 95122   Southwest Airlines Co.    ATL      Atlanta, GA  LGA   New York, NY
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 188444  2020        1      1               2
# 187960  2020        1      2               2
# ...

# %%
#Atl_LGA_Spirit_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Spirit Air Lines')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 1000)]
#Atl_LGA_Spirit_20_Sorted = Atl_LGA_Spirit_20.sort_values("MONTH")
#tl_LGA_Spirit_20_Sorted.head()
# Out:
# Empty DataFrame
# Columns: [PASSENGERS, FREIGHT, DISTANCE, UNIQUE_CARRIER_NAME, CARRIER_NAME, ORIGIN, ORIGIN_CITY_NAME, DEST, DEST_CITY_NAME, YEAR, QUARTER, MONTH, DISTANCE_GROUP]
# Index: []

# %%
plt.title("Delta's Market Share, Route ATL to LGA(New York), 2019  Passenger Volume")
plt.xlabel("Months")
plt.ylabel("Passengers")

plt.scatter(x_values_19_Pass, y_values_19_Pass, marker="o", facecolors="blue", edgecolors="black")
plt.scatter(x_values_19_American, y_values_19_American, marker="o", facecolors="red", edgecolors="blue")
plt.scatter(x_values_19_Frontier, y_values_19_Frontier, marker="o", facecolors="green", edgecolors="black")
plt.scatter(x_values_19_SW, y_values_19_SW, marker="o", facecolors="orange", edgecolors="black")
#plt.scatter(x_values_19_Spirit, y_values_19_Spirit, marker="o", facecolors="Yellow", edgecolors="black")
ax2 = plt.subplot(111)
ax2.plot(x_values_19_Pass, y_values_19_Pass, label='Delta')
ax2.plot(x_values_19_American, y_values_19_American, label='American Airlines')
ax2.plot(x_values_19_Frontier, y_values_19_Frontier, label='Frontier')
ax2.plot(x_values_19_SW, y_values_19_SW, label='SouthWest')
#ax2.plot(x_values_19_Spirit, y_values_19_Spirit, label='Spirit')
ax2.legend(loc='lower right', bbox_to_anchor=(1,.29), shadow=True, ncol=1)
# Out:
# /Users/ricardobenitez/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.

# %%
Atl_LGA_American_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 1000)]
Atl_LGA_American_20_Sorted = Atl_LGA_American_20.sort_values("MONTH")

# %%
y_values_20_American = Atl_LGA_American_20_Sorted['PASSENGERS']

# %%
x_values_20_American = Atl_LGA_American_20_Sorted['MONTH']

# %%
Atl_LGA_Frontier_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 1000)]
Atl_LGA_Frontier_20_Sorted = Atl_LGA_Frontier_20.sort_values("MONTH")
Atl_LGA_Frontier_20_Sorted
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 167653        3834        0       762  Frontier Airlines Inc.
# 166792        3724        0       762  Frontier Airlines Inc.
# 152583        2360        0       762  Frontier Airlines Inc.
# 155836        2611        0       762  Frontier Airlines Inc.
# 138040        1494        0       762  Frontier Airlines Inc.
# 149321        2131        0       762  Frontier Airlines Inc.
# 154672        2522        0       762  Frontier Airlines Inc.
# 158004        2789        0       762  Frontier Airlines Inc.
# 161466        3107        0       762  Frontier Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 167653  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 166792  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# 152583  Frontier Airlines Inc.    ATL      Atlanta, GA  LGA   New York, NY
# ...

# %%
y_values_20_Frontier = Atl_LGA_Frontier_20_Sorted['PASSENGERS']

# %%
x_values_20_Frontier = Atl_LGA_Frontier_20_Sorted['MONTH']

# %%
Atl_LGA_SW_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 30)]
Atl_LGA_SW_20_Sorted = Atl_LGA_SW_20.sort_values("MONTH")
Atl_LGA_SW_20_Sorted
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 188444       13990    31586       762  Southwest Airlines Co.
# 187960       13173    28422       762  Southwest Airlines Co.
# 180591        7080    30909       762  Southwest Airlines Co.
# 117787         701    36257       762  Southwest Airlines Co.
# 95122          147     5587       762  Southwest Airlines Co.
# 176113        5544    25023       762  Southwest Airlines Co.
# 173518        4872    30253       762  Southwest Airlines Co.
# 171363        4436    31772       762  Southwest Airlines Co.
# 174166        5022    44056       762  Southwest Airlines Co.
# 176336        5609    69216       762  Southwest Airlines Co.
# 172054        4571    61936       762  Southwest Airlines Co.
# 177033        5822    61791       762  Southwest Airlines Co.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST DEST_CITY_NAME  \
# 188444  Southwest Airlines Co.    ATL      Atlanta, GA  LGA   New York, NY
# ...

# %%
y_values_20_SW = Atl_LGA_SW_20_Sorted['PASSENGERS']

# %%
x_values_20_SW = Atl_LGA_SW_20_Sorted['MONTH']

# %%
#Atl_LGA_Spirit_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Spirit Air Lines')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LGA')&(airline_2020_df['PASSENGERS']>= 30)]
#Atl_LGA_Spirit_20_Sorted = Atl_LGA_Spirit_20.sort_values("MONTH")
#Atl_LGA_Spirit_20_Sorted

# %%
#y_values_20_Spirit = Atl_LGA_Spirit_20_Sorted['PASSENGERS']

# %%
#x_values_20_Spirit = Atl_LGA_Spirit_20_Sorted['MONTH']

# %%
plt.title("Delta's Market Share, Route ATL to LGA (New York), 2020  Passenger Volume")
plt.xlabel("Months")
plt.ylabel("Passengers")

plt.scatter(x_values_20_Pass, y_values_20_Pass, marker="o", facecolors="blue", edgecolors="black")
plt.scatter(x_values_20_American, y_values_20_American, marker="o", facecolors="red", edgecolors="blue")
plt.scatter(x_values_20_Frontier, y_values_20_Frontier, marker="o", facecolors="green", edgecolors="black")
plt.scatter(x_values_20_SW, y_values_20_SW, marker="o", facecolors="orange", edgecolors="black")
#plt.scatter(x_values_20_Spirit, y_values_20_Spirit, marker="o", facecolors="Yellow", edgecolors="black")
ax3 = plt.subplot(111)
ax3.plot(x_values_20_Pass, y_values_20_Pass, label='Delta')
ax3.plot(x_values_20_American, y_values_20_American, label='American Airlines')
ax3.plot(x_values_20_Frontier, y_values_20_Frontier, label='Frontier')
ax3.plot(x_values_20_SW, y_values_20_SW, label='SouthWest')
#ax3.plot(x_values_20_Spirit, y_values_20_Spirit, label='Spirit')
ax3.legend(loc='lower right', bbox_to_anchor=(1,.6), shadow=True, ncol=1)
# Out:
# /Users/ricardobenitez/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.
