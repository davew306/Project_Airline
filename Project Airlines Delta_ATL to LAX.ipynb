# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_2019_path = "2019AirlineData.csv"
csv_2020_path = "2020AirlineData.csv"

# %%
airline_2019_df = pd.read_csv(csv_2019_path, encoding="utf-8")
airline_2019_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE  \
# 0           0        0      1545
# 1           0        0       770
# 2           0        0      1067
# 3           0        0      1329
# 4           0        0      1018
#
#                                  UNIQUE_CARRIER_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 4  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
#
#                                         CARRIER_NAME ORIGIN ORIGIN_CITY_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# ...

# %%
Delta_Atl = airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Delta Air Lines Inc.')&(airline_2019_df['ORIGIN']=='ATL')& (airline_2019_df['DEST']=='LAX')& (airline_2019_df['PASSENGERS']>= 1000)]
Delta_Atl.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 251330       54199   692838      1947  Delta Air Lines Inc.
# 251434       56923   650155      1947  Delta Air Lines Inc.
# 251443       57201   717062      1947  Delta Air Lines Inc.
# 251499       58748   838368      1947  Delta Air Lines Inc.
# 251535       60466   678805      1947  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 251330  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 251434  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 251443  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 251499  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 251535  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 251330  2019        4     11               4
# 251434  2019        1      2               4
# ...

# %%
Delta_Atl_Lax = Delta_Atl.sort_values("MONTH", ascending=True)
Delta_Atl_Lax.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 251535       60466   678805      1947  Delta Air Lines Inc.
# 251434       56923   650155      1947  Delta Air Lines Inc.
# 251625       66148   938014      1947  Delta Air Lines Inc.
# 251607       65328   551182      1947  Delta Air Lines Inc.
# 251674       70879   601162      1947  Delta Air Lines Inc.
# 251672       70760   611265      1947  Delta Air Lines Inc.
# 251723       75863   622826      1947  Delta Air Lines Inc.
# 251683       71557   584309      1947  Delta Air Lines Inc.
# 251443       57201   717062      1947  Delta Air Lines Inc.
# 251499       58748   838368      1947  Delta Air Lines Inc.
# 251330       54199   692838      1947  Delta Air Lines Inc.
# 251601       64793   815399      1947  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 251535  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
Delta_Atl_Lax
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 251535       60466   678805      1947  Delta Air Lines Inc.
# 251434       56923   650155      1947  Delta Air Lines Inc.
# 251625       66148   938014      1947  Delta Air Lines Inc.
# 251607       65328   551182      1947  Delta Air Lines Inc.
# 251674       70879   601162      1947  Delta Air Lines Inc.
# 251672       70760   611265      1947  Delta Air Lines Inc.
# 251723       75863   622826      1947  Delta Air Lines Inc.
# 251683       71557   584309      1947  Delta Air Lines Inc.
# 251443       57201   717062      1947  Delta Air Lines Inc.
# 251499       58748   838368      1947  Delta Air Lines Inc.
# 251330       54199   692838      1947  Delta Air Lines Inc.
# 251601       64793   815399      1947  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 251535  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
# import calendar
# listmonths = Delta_Atl_Lax['MONTH']
# for x in listmonths:
#     #print(calendar.month_name[x])
#     Delta_Atl_Lax.loc[(x-1),'MONTH']= calendar.month_name[x]
    
# Delta_Atl_Lax

# %%
airline_2020_df = pd.read_csv(csv_2020_path, encoding="utf-8")
airline_2020_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE UNIQUE_CARRIER_NAME      CARRIER_NAME ORIGIN  \
# 0           0        0       104    Republic Airline  Republic Airline    RSW
# 1           0        0        77    Republic Airline  Republic Airline    RSW
# 2           0        0        30    Republic Airline  Republic Airline    SAV
# 3           0        0       228    Republic Airline  Republic Airline    STL
# 4           0        0       466    Republic Airline  Republic Airline    LNK
#
#   ORIGIN_CITY_NAME DEST              DEST_CITY_NAME  YEAR  QUARTER  MONTH  \
# 0   Fort Myers, FL  MIA                   Miami, FL  2020        1      1
# 1   Fort Myers, FL  SRQ      Sarasota/Bradenton, FL  2020        1      1
# 2     Savannah, GA  HHH             Hilton Head, SC  2020        1      1
# 3    St. Louis, MO  CID  Cedar Rapids/Iowa City, IA  2020        1      1
# 4      Lincoln, NE  ORD                 Chicago, IL  2020        1      1
#
#    DISTANCE_GROUP
# 0               1
# ...

# %%
Delta_Atl_20 = airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Delta Air Lines Inc.')&(airline_2020_df['ORIGIN']=='ATL')& (airline_2020_df['DEST']=='LAX')& (airline_2020_df['PASSENGERS']>= 1000)]
Delta_Atl_20.head()
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 179393        6598   167779      1947  Delta Air Lines Inc.
# 186551       11187   231676      1947  Delta Air Lines Inc.
# 189606       16658   522987      1947  Delta Air Lines Inc.
# 190873       21958   554734      1947  Delta Air Lines Inc.
# 191629       28869   374902      1947  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 179393  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 186551  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 189606  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 190873  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 191629  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 179393  2020        2      4               4
# 186551  2020        2      5               4
# ...

# %%
Delta_Atl_Lax_20 = Delta_Atl_20.sort_values("MONTH", ascending=True)
Delta_Atl_Lax_20.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE   UNIQUE_CARRIER_NAME  \
# 192339       60731   749453      1947  Delta Air Lines Inc.
# 192320       54819   882911      1947  Delta Air Lines Inc.
# 191679       29447   537254      1947  Delta Air Lines Inc.
# 179393        6598   167779      1947  Delta Air Lines Inc.
# 186551       11187   231676      1947  Delta Air Lines Inc.
# 189606       16658   522987      1947  Delta Air Lines Inc.
# 190873       21958   554734      1947  Delta Air Lines Inc.
# 191629       28869   374902      1947  Delta Air Lines Inc.
# 191647       29029   422375      1947  Delta Air Lines Inc.
# 191718       29927   274986      1947  Delta Air Lines Inc.
# 191680       29452   458259      1947  Delta Air Lines Inc.
# 191673       29356   472454      1947  Delta Air Lines Inc.
#
#                 CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 192339  Delta Air Lines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
Delta_ATL_LA_19_20 = pd.merge(Delta_Atl_Lax, Delta_Atl_Lax_20, how="outer")

# %%
y_values_19_Pass = Delta_Atl_Lax['PASSENGERS']

# %%
x_values_19_Pass=Delta_Atl_Lax['MONTH']

# %%
y_values_20_Pass = Delta_Atl_Lax_20['PASSENGERS']

# %%
x_values_20_Pass = Delta_Atl_Lax_20['MONTH']

# %%
plt.title("Delta Route ATL to LAX, 2019 vs 2020 Passenger Volume")
plt.xlabel("Months")
plt.ylabel("Passengers")

plt.scatter(x_values_19_Pass, y_values_19_Pass, marker="o", facecolors="blue", edgecolors="black")
plt.scatter(x_values_20_Pass, y_values_20_Pass, marker="o", facecolors="red", edgecolors="black")

ax = plt.subplot(111)
ax.plot(x_values_19_Pass, y_values_19_Pass, label='2019 Passengers')
ax.plot(x_values_20_Pass, y_values_20_Pass, label='2020 Passengers')
ax.legend(loc='lower right', bbox_to_anchor=(1, .08), shadow=True, ncol=1)
# Out:
# <ipython-input-106-8a038a7da955>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)

# %%
y_values_19_Freight = Delta_Atl_Lax['FREIGHT']

# %%
x_values_19_Freight=Delta_Atl_Lax['MONTH']

# %%
y_values_20_Freight = Delta_Atl_Lax_20['FREIGHT']

# %%
x_values_20_Freight =Delta_Atl_Lax_20['MONTH']

# %%
plt.title("Delta Route ATL to LAX, 2019 vs 2020 Freight Volume")
plt.xlabel("Months")
plt.ylabel("Freight (Pounds)")

plt.scatter(x_values_19, y_values_19_Freight, marker="o", facecolors="green", edgecolors="black")
plt.scatter(x_values_20, y_values_20_Freight, marker="o", facecolors="orange", edgecolors="black")

ax1 = plt.subplot(111)
ax1.plot(x_values_19_Freight, y_values_19_Freight, label='2019 Freight')
ax1.plot(x_values_20_Freight, y_values_20_Freight, label='2020 Freight')
ax1.legend(loc='lower right', bbox_to_anchor=(1,-.025), shadow=True, ncol=1)
# Out:
# <ipython-input-111-4005fe7e836a>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1 = plt.subplot(111)

# %%
Atl_Lax_Market = airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Delta Air Lines Inc.')& (airline_2019_df['CARRIER_NAME']=='United Air Lines Inc.')& (airline_2019_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2019_df['CARRIER_NAME']=='Spirit Air Lines')&airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2019_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LAX')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_Lax_Market.head()
# Out:
#   File "<ipython-input-113-3bbb31796487>", line 2
#     Atl_Lax_Market.head()
#     ^
# SyntaxError: invalid syntax

# %%
Atl_Lax_American_19= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LAX')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_Lax_American_19_Sorted = Atl_Lax_American.sort_values("MONTH")
Atl_Lax_American_19_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 234183       11898     3574      1947  American Airlines Inc.
# 233746       11666      506      1947  American Airlines Inc.
# 234193       11902     1418      1947  American Airlines Inc.
# 227498        9038      956      1947  American Airlines Inc.
# 236323       13159     1485      1947  American Airlines Inc.
# 236324       13159      946      1947  American Airlines Inc.
# 235440       12611     4148      1947  American Airlines Inc.
# 231948       10775      952      1947  American Airlines Inc.
# 233255       11405     1494      1947  American Airlines Inc.
# 236644       13378     4649      1947  American Airlines Inc.
# 234980       12324     1069      1947  American Airlines Inc.
# 240565       16698     3145      1947  American Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 234183  American Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
y_values_19_American = Atl_Lax_American_19_Sorted['PASSENGERS']

# %%
x_values_19_American = Atl_Lax_American_19_Sorted['MONTH']

# %%
Atl_Lax_Frontier_19= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LAX')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_Lax_Frontier_19_Sorted = Atl_Lax_Frontier_19.sort_values("MONTH")
Atl_Lax_Frontier_19_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 165292        2068        0      1947  Frontier Airlines Inc.
# 160674        1856        0      1947  Frontier Airlines Inc.
# 167119        2158        0      1947  Frontier Airlines Inc.
# 162652        1946        0      1947  Frontier Airlines Inc.
# 167454        2177        0      1947  Frontier Airlines Inc.
# 167657        2187        0      1947  Frontier Airlines Inc.
# 165857        2096        0      1947  Frontier Airlines Inc.
# 167363        2171        0      1947  Frontier Airlines Inc.
# 162940        1959        0      1947  Frontier Airlines Inc.
# 164654        2039        0      1947  Frontier Airlines Inc.
# 162487        1938        0      1947  Frontier Airlines Inc.
# 171303        2396        0      1947  Frontier Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 165292  Frontier Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
y_values_19_Frontier = Atl_Lax_Frontier_19_Sorted['PASSENGERS']

# %%
x_values_19_Frontier = Atl_Lax_Frontier_19_Sorted['MONTH']

# %%
Atl_Lax_SW_19= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LAX')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_Lax_SW_19_Sorted = Atl_Lax_SW_19.sort_values("MONTH")
Atl_Lax_SW_19_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 232944       11259    39846      1947  Southwest Airlines Co.
# 232848       11212    37546      1947  Southwest Airlines Co.
# 234834       12250    30088      1947  Southwest Airlines Co.
# 234451       12032    29025      1947  Southwest Airlines Co.
# 233670       11619    38864      1947  Southwest Airlines Co.
# 233915       11757    37331      1947  Southwest Airlines Co.
# 234649       12143    31114      1947  Southwest Airlines Co.
# 225256        8390    25839      1947  Southwest Airlines Co.
# 224361        8161    27025      1947  Southwest Airlines Co.
# 225316        8404    34378      1947  Southwest Airlines Co.
# 224517        8201    24864      1947  Southwest Airlines Co.
# 230577       10175    25393      1947  Southwest Airlines Co.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 232944  Southwest Airlines Co.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
y_values_19_SW = Atl_Lax_SW_19_Sorted['PASSENGERS']

# %%
x_values_19_SW = Atl_Lax_SW_19_Sorted['MONTH']

# %%
Atl_Lax_Spirit_19= airline_2019_df[(airline_2019_df['CARRIER_NAME']=='Spirit Air Lines')&(airline_2019_df['ORIGIN']=='ATL')&(airline_2019_df['DEST']=='LAX')&(airline_2019_df['PASSENGERS']>= 1000)]
Atl_Lax_Spirit_Sorted = Atl_Lax_Spirit_19.sort_values("MONTH")
Atl_Lax_Spirit_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE UNIQUE_CARRIER_NAME      CARRIER_NAME  \
# 177155        2774        0      1947    Spirit Air Lines  Spirit Air Lines
# 183956        3237        0      1947    Spirit Air Lines  Spirit Air Lines
# 188862        3552        0      1947    Spirit Air Lines  Spirit Air Lines
# 187514        3470        0      1947    Spirit Air Lines  Spirit Air Lines
# 204209        4689        0      1947    Spirit Air Lines  Spirit Air Lines
# 200084        4313        0      1947    Spirit Air Lines  Spirit Air Lines
# 196336        4037        0      1947    Spirit Air Lines  Spirit Air Lines
# 197705        4135        0      1947    Spirit Air Lines  Spirit Air Lines
# 207744        5058        0      1947    Spirit Air Lines  Spirit Air Lines
# 210139        5343        0      1947    Spirit Air Lines  Spirit Air Lines
# 201491        4439        0      1947    Spirit Air Lines  Spirit Air Lines
# ...

# %%
y_values_19_Spirit = Atl_Lax_Spirit_Sorted['PASSENGERS']

# %%
x_values_19_Spirit = Atl_Lax_Spirit_Sorted['MONTH']

# %%
Atl_Lax_American_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 100)]
Atl_Lax_American_20_Sorted = Atl_Lax_American_20.sort_values("MONTH")
Atl_Lax_American_20_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 187604       12602     3208      1947  American Airlines Inc.
# 187285       12140     1423      1947  American Airlines Inc.
# 179951        6815      434      1947  American Airlines Inc.
# 105065         317      309      1947  American Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 187604  American Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 187285  American Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 179951  American Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 105065  American Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 187604  2020        1      1               4
# 187285  2020        1      2               4
# 179951  2020        1      3               4
# 105065  2020        2      4               4

# %%
Atl_Lax_Frontier_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 100)]
Atl_Lax_Frontier_20_Sorted = Atl_Lax_Frontier_20.sort_values("MONTH")
Atl_Lax_Frontier_20_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 143113        1759        0      1947  Frontier Airlines Inc.
# 139619        1570        0      1947  Frontier Airlines Inc.
# 130629        1171        0      1947  Frontier Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 143113  Frontier Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 139619  Frontier Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 130629  Frontier Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 143113  2020        1      1               4
# 139619  2020        1      2               4
# 130629  2020        1      3               4

# %%
Atl_Lax_SW_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 25)]
Atl_Lax_SW_20_Sorted = Atl_Lax_SW_20.sort_values("MONTH")
Atl_Lax_SW_20_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 182509        7974    30636      1947  Southwest Airlines Co.
# 181408        7433    40291      1947  Southwest Airlines Co.
# 172940        4749    28492      1947  Southwest Airlines Co.
# 117590         694    16364      1947  Southwest Airlines Co.
# 151609        2290    28834      1947  Southwest Airlines Co.
# 173762        4925    32893      1947  Southwest Airlines Co.
# 179770        6742    51542      1947  Southwest Airlines Co.
# 166804        3726    24489      1947  Southwest Airlines Co.
# 119229         750     4668      1947  Southwest Airlines Co.
# 107129         371     3793      1947  Southwest Airlines Co.
# 91433          121     2569      1947  Southwest Airlines Co.
# 76048           42        0      1947  Southwest Airlines Co.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 182509  Southwest Airlines Co.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
Atl_Lax_Spirit_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Spirit Air Lines')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 1000)]
Atl_Lax_Spirit_20_Sorted = Atl_Lax_Spirit_20.sort_values("MONTH")
Atl_Lax_Spirit_20_Sorted.head(15)
# Out:
#         PASSENGERS  FREIGHT  DISTANCE UNIQUE_CARRIER_NAME      CARRIER_NAME  \
# 161811        3141        0      1947    Spirit Air Lines  Spirit Air Lines
# 161346        3096        0      1947    Spirit Air Lines  Spirit Air Lines
# 154264        2490        0      1947    Spirit Air Lines  Spirit Air Lines
# 168771        4002        0      1947    Spirit Air Lines  Spirit Air Lines
# 184488        9257        0      1947    Spirit Air Lines  Spirit Air Lines
# 184300        9105        0      1947    Spirit Air Lines  Spirit Air Lines
# 183933        8849        0      1947    Spirit Air Lines  Spirit Air Lines
# 185237        9883        0      1947    Spirit Air Lines  Spirit Air Lines
# 186463       11092        0      1947    Spirit Air Lines  Spirit Air Lines
# 184468        9245        0      1947    Spirit Air Lines  Spirit Air Lines
#
#        ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  YEAR  QUARTER  MONTH  \
# ...

# %%
plt.title("Delta's Market Share, Route ATL to LAX, 2019  Passenger Volume")
plt.xlabel("Months")
plt.ylabel("Passengers")

plt.scatter(x_values_19_Pass, y_values_19_Pass, marker="o", facecolors="blue", edgecolors="black")
plt.scatter(x_values_19_American, y_values_19_American, marker="o", facecolors="red", edgecolors="blue")
plt.scatter(x_values_19_Frontier, y_values_19_Frontier, marker="o", facecolors="green", edgecolors="black")
plt.scatter(x_values_19_SW, y_values_19_SW, marker="o", facecolors="orange", edgecolors="black")
plt.scatter(x_values_19_Spirit, y_values_19_Spirit, marker="o", facecolors="Yellow", edgecolors="black")
ax2 = plt.subplot(111)
ax2.plot(x_values_19_Pass, y_values_19_Pass, label='Delta')
ax2.plot(x_values_19_American, y_values_19_American, label='American Airlines')
ax2.plot(x_values_19_Frontier, y_values_19_Frontier, label='Frontier')
ax2.plot(x_values_19_SW, y_values_19_SW, label='SouthWest')
ax2.plot(x_values_19_Spirit, y_values_19_Spirit, label='Spirit')
ax2.legend(loc='lower right', bbox_to_anchor=(1,.29), shadow=True, ncol=1)
# Out:
# <ipython-input-177-6ef8edd40835>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax2 = plt.subplot(111)

# %%
Atl_Lax_American_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='American Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 1000)]
Atl_Lax_American_20_Sorted = Atl_Lax_American_20.sort_values("MONTH")

# %%
y_values_20_American = Atl_Lax_American_20_Sorted['PASSENGERS']

# %%
x_values_20_American = Atl_Lax_American_20_Sorted['MONTH']

# %%
Atl_Lax_Frontier_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Frontier Airlines Inc.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 1000)]
Atl_Lax_Frontier_20_Sorted = Atl_Lax_Frontier_20.sort_values("MONTH")
Atl_Lax_Frontier_20_Sorted
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 143113        1759        0      1947  Frontier Airlines Inc.
# 139619        1570        0      1947  Frontier Airlines Inc.
# 130629        1171        0      1947  Frontier Airlines Inc.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 143113  Frontier Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 139619  Frontier Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# 130629  Frontier Airlines Inc.    ATL      Atlanta, GA  LAX  Los Angeles, CA
#
#         YEAR  QUARTER  MONTH  DISTANCE_GROUP
# 143113  2020        1      1               4
# 139619  2020        1      2               4
# 130629  2020        1      3               4

# %%
y_values_20_Frontier = Atl_Lax_Frontier_20_Sorted['PASSENGERS']

# %%
x_values_20_Frontier = Atl_Lax_Frontier_20_Sorted['MONTH']

# %%
Atl_Lax_SW_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Southwest Airlines Co.')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 30)]
Atl_Lax_SW_20_Sorted = Atl_Lax_SW_20.sort_values("MONTH")
Atl_Lax_SW_20_Sorted
# Out:
#         PASSENGERS  FREIGHT  DISTANCE     UNIQUE_CARRIER_NAME  \
# 182509        7974    30636      1947  Southwest Airlines Co.
# 181408        7433    40291      1947  Southwest Airlines Co.
# 172940        4749    28492      1947  Southwest Airlines Co.
# 117590         694    16364      1947  Southwest Airlines Co.
# 151609        2290    28834      1947  Southwest Airlines Co.
# 173762        4925    32893      1947  Southwest Airlines Co.
# 179770        6742    51542      1947  Southwest Airlines Co.
# 166804        3726    24489      1947  Southwest Airlines Co.
# 119229         750     4668      1947  Southwest Airlines Co.
# 107129         371     3793      1947  Southwest Airlines Co.
# 91433          121     2569      1947  Southwest Airlines Co.
# 76048           42        0      1947  Southwest Airlines Co.
#
#                   CARRIER_NAME ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  \
# 182509  Southwest Airlines Co.    ATL      Atlanta, GA  LAX  Los Angeles, CA
# ...

# %%
y_values_20_SW = Atl_Lax_SW_20_Sorted['PASSENGERS']

# %%
x_values_20_SW = Atl_Lax_SW_20_Sorted['MONTH']

# %%
Atl_Lax_Spirit_20= airline_2020_df[(airline_2020_df['CARRIER_NAME']=='Spirit Air Lines')&(airline_2020_df['ORIGIN']=='ATL')&(airline_2020_df['DEST']=='LAX')&(airline_2020_df['PASSENGERS']>= 30)]
Atl_Lax_Spirit_20_Sorted = Atl_Lax_Spirit_20.sort_values("MONTH")
Atl_Lax_Spirit_20_Sorted
# Out:
#         PASSENGERS  FREIGHT  DISTANCE UNIQUE_CARRIER_NAME      CARRIER_NAME  \
# 161811        3141        0      1947    Spirit Air Lines  Spirit Air Lines
# 161346        3096        0      1947    Spirit Air Lines  Spirit Air Lines
# 154264        2490        0      1947    Spirit Air Lines  Spirit Air Lines
# 108929         421        0      1947    Spirit Air Lines  Spirit Air Lines
# 168771        4002        0      1947    Spirit Air Lines  Spirit Air Lines
# 184488        9257        0      1947    Spirit Air Lines  Spirit Air Lines
# 184300        9105        0      1947    Spirit Air Lines  Spirit Air Lines
# 183933        8849        0      1947    Spirit Air Lines  Spirit Air Lines
# 185237        9883        0      1947    Spirit Air Lines  Spirit Air Lines
# 186463       11092        0      1947    Spirit Air Lines  Spirit Air Lines
# 184468        9245        0      1947    Spirit Air Lines  Spirit Air Lines
#
# ...

# %%
y_values_20_Spirit = Atl_Lax_Spirit_20_Sorted['PASSENGERS']

# %%
x_values_20_Spirit = Atl_Lax_Spirit_20_Sorted['MONTH']

# %%
plt.title("Delta's Market Share, Route ATL to LAX, 2020  Passenger Volume")
plt.xlabel("Months")
plt.ylabel("Passengers")

plt.scatter(x_values_20_Pass, y_values_20_Pass, marker="o", facecolors="blue", edgecolors="black")
plt.scatter(x_values_20_American, y_values_20_American, marker="o", facecolors="red", edgecolors="blue")
plt.scatter(x_values_20_Frontier, y_values_20_Frontier, marker="o", facecolors="green", edgecolors="black")
plt.scatter(x_values_20_SW, y_values_20_SW, marker="o", facecolors="orange", edgecolors="black")
plt.scatter(x_values_20_Spirit, y_values_20_Spirit, marker="o", facecolors="Yellow", edgecolors="black")
ax3 = plt.subplot(111)
ax3.plot(x_values_20_Pass, y_values_20_Pass, label='Delta')
ax3.plot(x_values_20_American, y_values_20_American, label='American Airlines')
ax3.plot(x_values_20_Frontier, y_values_20_Frontier, label='Frontier')
ax3.plot(x_values_20_SW, y_values_20_SW, label='SouthWest')
ax3.plot(x_values_20_Spirit, y_values_20_Spirit, label='Spirit')
ax3.legend(loc='lower right', bbox_to_anchor=(1,.6), shadow=True, ncol=1)
# Out:
# <ipython-input-184-9a6f6de3a481>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax3 = plt.subplot(111)
