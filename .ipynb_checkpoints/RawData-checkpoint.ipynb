# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_2019_path = "2019_Raw_Data.csv"
csv_2020_path = "2020_Raw_Data.csv"

# %%
airline_2019_df = pd.read_csv(csv_2019_path, encoding="utf-8")
airline_2019_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE UNIQUE_CARRIER  \
# 0         0.0      0.0    1545.0             WL
# 1         0.0      0.0     770.0             WL
# 2         0.0      0.0    1067.0             WL
# 3         0.0      0.0    1329.0             WL
# 4         0.0      0.0    1018.0             WL
#
#                                  UNIQUE_CARRIER_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 4  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
#
#                                         CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...              10747
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...              10747
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...              10747
# ...

# %%
airline_2020_df = pd.read_csv(csv_2019_path, encoding="utf-8")
airline_2020_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE UNIQUE_CARRIER  \
# 0         0.0      0.0    1545.0             WL
# 1         0.0      0.0     770.0             WL
# 2         0.0      0.0    1067.0             WL
# 3         0.0      0.0    1329.0             WL
# 4         0.0      0.0    1018.0             WL
#
#                                  UNIQUE_CARRIER_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 4  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
#
#                                         CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...              10747
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...              10747
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...              10747
# ...

# %%
airline_2019_df = airline_2019_df.drop(['ORIGIN_AIRPORT_ID','UNIQUE_CARRIER', 'DEST_AIRPORT_ID', 'CLASS', 'Unnamed: 16'],axis=1)

# %%
airline_2019_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE  \
# 0         0.0      0.0    1545.0
# 1         0.0      0.0     770.0
# 2         0.0      0.0    1067.0
# 3         0.0      0.0    1329.0
# 4         0.0      0.0    1018.0
#
#                                  UNIQUE_CARRIER_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 4  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
#
#                                         CARRIER_NAME ORIGIN ORIGIN_CITY_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# ...

# %%
airline_2020_df = airline_2020_df.drop(['ORIGIN_AIRPORT_ID','UNIQUE_CARRIER','DEST_AIRPORT_ID', 'CLASS', 'Unnamed: 16'],axis=1)

# %%
airline_2020_df.head()
# Out:
#    PASSENGERS  FREIGHT  DISTANCE  \
# 0         0.0      0.0    1545.0
# 1         0.0      0.0     770.0
# 2         0.0      0.0    1067.0
# 3         0.0      0.0    1329.0
# 4         0.0      0.0    1018.0
#
#                                  UNIQUE_CARRIER_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
# 4  Caribbean Sun Airlines, Inc. d/b/a World Atlan...
#
#                                         CARRIER_NAME ORIGIN ORIGIN_CITY_NAME  \
# 0  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 1  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 2  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# 3  Caribbean Sun Airlines, Inc. d/b/a World Atlan...    BRO  Brownsville, TX
# ...

# %%
airline_2019_df.to_csv('2019AirlineDataJ.csv', index = False)

# %%
airline_2020_df.to_csv('2020AirlineDataJ.csv', index = False)
